# %% [markdown]
# <a href="https://colab.research.google.com/github/pa1kpuram/projects/blob/main/Aerofit_Business_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Business Case: Aerofit -  Descriptive Statistics & Probability**

# %% [markdown]
# # **Table of Contents**
#
# **Table of contents**
#
# **Title :Business Case: Aerofit - Descriptive Statistics & Probability**
#
# 1. **Introduction**
# 2. **Exploratory Data Analysis**
#
#     📊 Statistical Summary of Aerofit Dataset
#
#     👥 Duplicate Discovery
#
#     🔍📈Detecting Outliers
#
# 3. **📊 Data Visualization: Exploring Insights with Graphs**
#
#     3.1 Exploring Relationship between Categorical Variables and Product Purchased
#
#     3.2 Analysis of Marginal Probability: Customer Preferences for Product Purchases
#
#     3.3 Exploring Relationships: Correlation Heatmap of Numerical Features
#
#     3.4 Analysis of Gender-Based Conditional Probability in Product Purchases
#
#     3.5 Customer Profiles Analysis by Product
#
#
# 4 **Business Recommendations**

# %% [markdown]
# # **1.Introduction**

# %% [markdown]
# **🌟 Welcome to Aerofit: Where Fitness Meets Innovation! 🏋️‍♂️💪:**
#
# Aerofit is a leading brand in the fitness equipment industry, offering a wide range of products such as treadmills, exercise bikes, gym equipment, and accessories.Committed to innovation and customer satisfaction, Aerofit provides solutions for users of all fitness levels. With a focus on quality and accessibility, Aerofit strives to promote health and wellness by making fitness equipment that is both effective and user-friendly.
#
# **Business Problem:**
#
# Aerofit aims to refine its marketing strategies and product offerings by identifying customer characteristics for each treadmill product. 🎯 The challenge lies in leveraging data analytics to create customer profiles, analyze purchasing behavior, and optimize recommendations, ultimately driving business growth in the fitness equipment market. 📈🔍
#
# **Objective:**
#
# Utilize advanced data analytics techniques to develop detailed customer profiles for each Aerofit treadmill product. 📊 Analyze purchasing behavior patterns to understand customer preferences, demographics, and characteristics. 🛒 With these insights, optimize marketing strategies and product recommendations to enhance customer targeting and satisfaction. 🎯 Ultimately, the objective is to leverage data-driven approaches to drive business growth and maintain Aerofit's competitive edge in the dynamic fitness equipment market. 🚀
#
#
#
# | Feature       | Description                                              |
# |---------------|----------------------------------------------------------|
# | Product       | Type of treadmill purchased by the customer.             |
# | Age           | Age of the customer in years.                            |
# | Gender        | Gender of the customer.                                  |
# | Education     | Number of years of education completed by the customer.  |
# | MaritalStatus| Marital status of the customer.                          |
# | Usage         | Average number of times per week the treadmill is used.  |
# | Income        | Annual income of the customer in dollars.                |
# | Fitness       | Self-rated fitness level of the customer on a scale of 1 to 5, where 1 is poor shape and 5 is excellent shape. |
# | Miles         | Average number of miles expected to walk/run per week.    |

# %% [markdown]
# # **2. Exploratory Data Analysis**

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import copy

# %%
# loading the dataset
df = pd.read_csv('/content/aerofit.csv')

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   KP781   40   Male         21        Single      6        5   83416
# 176   KP781   42   Male         18        Single      5        4   89641
# 177   KP781   45   Male         16        Single      5        5   90886
# 178   KP781   47   Male         18     Partnered      4        5  104581
# 179   KP781   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.shape
# Out:
# (180, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# #### 🔍 **Insights**
#
#
# - The dataset contains 9 features with alphanumeric data, covering customer demographics, usage patterns, and fitness preferences.
#
# - No missing values are found in any columns, ensuring data completeness and reliability.
#
# - All column data types are appropriate, but converting 'Usage' and 'Fitness' columns to str(object) for consistency is suggested.
#
# - These insights provide a robust basis for further analysis and decision-making at Aerofit.

# %% [markdown]
# ## **📊 Statistical Summary of Aerofit Dataset**

# %%
# statisctical summary of numerical data type columns
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# #### **🔍 Insights**
#
# 1. **Age** - Participants' ages range from 18 to 50 years, with an average age of 29 years.
#
# 2. **Education** - Participant education levels vary between 12 and 21 years, with an average education duration of 16 years.
#
# 3. **Usage** - Participants plan to use the product anywhere from 2 to 7 times per week, averaging 3 times per week.
#
# 4. **Fitness** - On average, participants rate their fitness at 3 on a 5-point scale, indicating a moderate level of fitness.
#
# 5. **Income** - Participants' annual incomes fall between USD 30,000 and USD 100,000, with an average income of around USD 54,000.
#
# 6. **Miles** - Participants aim to cover weekly running distances ranging from 21 to 360 miles, with an average goal of 103 miles per week.

# %%
# statisctical summary of object type columns
df.describe(include='object')
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %% [markdown]
# ### **🔍 Insights**
#
# 1. **Product**: Over the past three months, the KP281 product demonstrated the highest sales performance among the three products, accounting for approximately 44% of total sales.
#
# 2. **Gender**: Based on the data from the last 3 months, around 58% of buyers were male, while 42% were female.
#
# 3. **Marital Status**: According to the data from the last 3 months, approximately 60% of buyers were married, whereas 40% were single.

# %% [markdown]
# ## 👥 **Duplicate Discovery**

# %%
df.duplicated().value_counts()
# Out:
# False    180
# Name: count, dtype: int64

# %% [markdown]
# #### **🔍 Insights**
# - No duplicates were found among the 180 entries in the dataset.

# %% [markdown]
# ## **Detecting Outliers**

# %% [markdown]
# ### **Visualizing Continuous Variables with Boxplots**

# %%
#Identify continuous variables (assuming all numerical columns are continuous)
continuous_variables = df.select_dtypes(include=['int', 'float']).columns

# Plot boxplots for each continuous variable
for variable in continuous_variables:
    sns.boxplot(x=df[variable])
    plt.title(f'Boxplot for {variable}')
    plt.show()

# %% [markdown]
# ### **Handling Outliers for Continuous Variables**

# %%
# Remove or clip outliers for each continuous variable
for variable in continuous_variables:
    lower_bound = df[variable].quantile(0.05)
    upper_bound = df[variable].quantile(0.95)
    df[variable] = np.clip(df[variable], lower_bound, upper_bound)

# Visualize the distribution of each continuous variable using boxplot
plt.figure(figsize=(10, 6))
df.boxplot()
plt.title('Boxplot of Continuous Variables after Clipping Outliers')
plt.xticks(rotation=45)
plt.grid(False)
plt.show()

# %% [markdown]
# # 3.📊 **Data Visualization: Exploring Insights with Graphs**

# %% [markdown]
# ### **Exploring Relationship between Categorical Variables and Product Purchased**

# %%
# Plot count plots to visualize the relationship between categorical variables and the output variable
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.countplot(x='MaritalStatus', hue='Product', data=df)
plt.title('Marital Status vs. Product Purchased')

plt.subplot(1, 2, 2)
sns.countplot(x='Gender', hue='Product', data=df)
plt.title('Gender vs. Product Purchased')

plt.tight_layout()
plt.show()

# %%
#Plot count plot for Age vs. Product Purchased
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', hue='Product', data=df)
plt.title('Age vs. Product Purchased')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **🔍 Insights**
#
# 1. **Marital Status vs. Product Purchased**:
#    - Among partnered individuals, KP281 is favored, while single individuals show a more balanced preference, with a slight inclination towards KP481.
#
# 2. **Gender vs. Product Purchased**:
#    - Male customers prefer KP281, while females lean slightly towards KP481.
#
# 3. **Age vs. Product Purchased**:
#    - Younger age groups, especially those aged 25-35, favor KP281, whereas older demographics exhibit a more balanced distribution across product types.
#
# These insights illuminate how marital status, gender, and age influence product preferences, guiding targeted marketing and product development strategies.

# %% [markdown]
# ### **Analysis of Marginal Probability: Customer Preferences for Product Purchases**

# %%
# Calculate the marginal probability of each product
marginal_probability = df['Product'].value_counts(normalize=True) * 100

# Display the marginal probability
print("Marginal Probability of Each Product:")
print(marginal_probability)

# Plot the bar plot
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Blue, Orange, Green
plt.figure(figsize=(8, 6))
marginal_probability.plot(kind='bar', color=colors)
plt.title('Marginal Probability of Each Product')
plt.xlabel('Product')
plt.ylabel('Probability (%)')
plt.xticks(rotation=0)
plt.show()
# Out:
# Marginal Probability of Each Product:
# Product
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: proportion, dtype: float64

# %%
#Calculate the probability that a customer buys a product based on each column
probability_based_on_column = {}

# Iterate over each column in the crosstab
for column in marginal_probability.columns:
    # Calculate the probability based on the marginal probability of each product
    probability_based_on_column[column] = marginal_probability.loc[:, column] / marginal_probability.loc[:, column].sum()

# Display the probabilities
print("Probability that the customer buys a product based on each column:")
print(probability_based_on_column)


# Plot the probabilities
plt.figure(figsize=(10, 6))
for i, (column, probability) in enumerate(probability_based_on_column.items()):
    plt.bar(probability.index, probability.values, label=column, color=colors[i])

plt.xlabel('Product')
plt.ylabel('Probability (%)')
plt.title('Probability of Customer Buying a Product Based on Each Column')
plt.legend(title='Column')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Probability that the customer buys a product based on each column:
# {'proportion': Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: proportion, dtype: float64}

# %% [markdown]
# #### **🔍 Insights**
#
# The marginal probability represents the percentage of customers who have purchased each product. Here are the insights based on the marginal probability of each product:
#
# 1. **KP281**: Approximately 44.44% of customers have purchased KP281, making it the most popular product among the three.
#
# 2. **KP481**: Around 33.33% of customers have purchased KP481, indicating a significant portion of the customer base prefers this product.
#
# 3. **KP781**: About 22.22% of customers have purchased KP781, making it the least purchased product among the three.
#
# These insights provide a clear understanding of the distribution of product purchases among customers, helping in strategic decision-making for product marketing and inventory management.

# %% [markdown]
# ## **Analysis of Gender-Based Conditional Probability in Product Purchases**

# %%
# Get unique product names
products = df['Product'].unique()

# Calculate the conditional probability for each product given each gender
conditional_probabilities = {}
for product in products:
    product_conditional_probabilities = {}
    for gender in df['Gender'].unique():
        event_A_and_B = len(df[(df['Gender'] == gender) & (df['Product'] == product)])
        event_B = len(df[df['Gender'] == gender])
        conditional_probability = event_A_and_B / event_B
        product_conditional_probabilities[gender] = conditional_probability
    conditional_probabilities[product] = product_conditional_probabilities

# Display the conditional probabilities
for product, probabilities in conditional_probabilities.items():
    print(f"Conditional Probability (Purchasing {product}):")
    for gender, probability in probabilities.items():
        print(f"{gender}: {probability}")
    print()

df_conditional = pd.DataFrame(conditional_probabilities)

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_conditional, annot=True, cmap='Blues', fmt=".2f")  # Previous colormap 'Blues'

# Add labels and title
plt.xlabel('Product')
plt.ylabel('Gender')
plt.title('Conditional Probability of Purchasing Each Product by Gender')

# Show plot
plt.show()
# Out:
# Conditional Probability (Purchasing KP281):
# Male: 0.38461538461538464
# Female: 0.5263157894736842
#
# Conditional Probability (Purchasing KP481):
# Male: 0.2980769230769231
# Female: 0.3815789473684211
#
# Conditional Probability (Purchasing KP781):
# Male: 0.3173076923076923
# Female: 0.09210526315789473

# %% [markdown]
# #### **🔍 Insights**
# - **KP281**: Female customers exhibit a higher likelihood (52.63%) of purchasing KP281 compared to male customers (38.46%).
# - **KP481**: Both male and female customers show a preference for KP481, with probabilities of 29.81% and 38.16%, respectively.
# - **KP781**: Male customers demonstrate a slightly higher likelihood (31.73%) of purchasing KP781 compared to female customers (9.21%).
#
#   This summary highlights the varying probabilities of product purchases between genders.

# %% [markdown]
# ## **Exploring Relationships: Correlation Heatmap of Numerical Features**

# %%
# Selecting only numerical columns
numerical_df = df.select_dtypes(include=['int', 'float'])

# Calculating the correlation matrix
correlation_matrix = numerical_df.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Adding title
plt.title('Correlation Heatmap')

# Displaying the plot
plt.show()

# %% [markdown]
# #### **🔍 Insights**
#
# 1. **Strong Positive Correlations**:
#    - The variables "Miles" and "Fitness" exhibit a strong positive correlation of approximately 0.83. This suggests that individuals who run more miles tend to rate their fitness levels higher, and vice versa.
#
# 2. **Moderate Positive Correlations**:
#    - There is a moderate positive correlation (around 0.77) between "Usage" and "Miles". This indicates that individuals who use the product more frequently tend to run more miles.
#
# 3. **Other Significant Correlations**:
#    - A notable positive correlation (about 0.66) exists between "Fitness" and "Usage". This implies that individuals who rate their fitness levels higher tend to use the product more frequently.
#
#    - Additionally, there is a moderate positive correlation (approximately 0.63) between "Education" and "Income", indicating that individuals with higher education levels tend to have higher incomes.
#
# 4. **Weak Correlations**:
#    - The correlation between "Age" and "Fitness" is weak (around 0.06), suggesting a minimal relationship between age and fitness levels.
#
#    - Similarly, the correlation between "Age" and "Miles" is weak (around 0.03), indicating a slight relationship between age and the distance individuals run.
#
# 5. **No Significant Correlations**:
#    - The variables "Age" and "Product_encoded" have very weak correlations (around 0.03), indicating little to no relationship between age and the encoded product category.
#
# Overall, the correlation analysis provides insights into the relationships between different features in the dataset, highlighting potential factors that may influence each other.

# %% [markdown]
# ## **Customer Profiles Analysis by Product**

# %%
# Selecting numerical columns and including 'Product'
numerical_df = df.select_dtypes(include=['int', 'float']).copy()
numerical_df['Product'] = df['Product']

# Grouping data by product and calculating mean values for numerical columns
product_profiles = numerical_df.groupby('Product').mean()

# Displaying customer profiles for each product
print("Customer Profiles for Each Product:")
print(product_profiles)
# Out:
# Customer Profiles for Each Product:
#             Age  Education     Usage   Fitness        Income    Miles  \
# Product
# KP281    28.425  15.125000  3.087500  2.975000  46588.574973   83.125
# KP481    28.800  15.183333  3.066667  2.916667  49049.449982   88.500
# KP781    28.825  17.050000  4.500000  4.625000  73894.275088  155.900
#
#          Product_encoded
# Product
# KP281                0.0
# KP481                1.0
# KP781                2.0

# %% [markdown]
# #### **🔍 Insights**
#
# 1. **Age**: The average age of customers purchasing product KP281 is approximately 28.43 years, while for KP481 and KP781, it is around 28.8 and 28.83 years, respectively. There's not a significant difference in the average age across the three products.
#
# 2. **Education**: Customers buying product KP281 have an average education duration of 15.13 years, slightly lower than those purchasing KP481 (15.18 years) and KP781 (17.05 years).
#
# 3. **Usage**: Product KP781 appears to have the highest average usage frequency among customers, with an average usage of 4.5 times per week, compared to 3.09 times for KP281 and 3.07 times for KP481.
#
# 4. **Fitness**: Customers buying KP781 have the highest average fitness rating, with a score of 4.62, followed by KP481 with 2.92 and KP281 with 2.98.
#
# 5. **Income**: The average income of customers purchasing KP781 is substantially higher compared to those purchasing KP281 and KP481. Customers buying KP781 have an average income of approximately USD 73,894, while for KP281 and KP481, it is around USD 46,589 and USD 49,049, respectively.
#
# 6. **Miles**: Customers buying KP781 have a significantly higher weekly running goal, averaging 155.9 miles, compared to 83.12 miles for KP281 and 88.5 miles for KP481.
#
# 7. **Product Encoded**: The product encoded variable indicates the product type, with KP281 encoded as 0, KP481 as 1, and KP781 as 2.

# %% [markdown]
# # **Business Recommendations**
#
# 1. **Product Preference**: Based on the customer profiles for each product, it's evident that each product attracts different demographics. KP281 seems to appeal to younger individuals with slightly lower education levels, moderate usage frequency, and lower fitness levels. KP481 attracts a similar demographic but with slightly higher education levels and usage frequency. On the other hand, KP781 caters to older individuals with higher education levels, higher usage frequency, and better fitness levels.
#
# 2. **Marketing Strategy**: Tailor marketing strategies for each product based on the identified customer profiles. Focus on highlighting the unique features of each product that resonate with the target demographic. For example, emphasize the affordability and versatility of KP281 for younger customers, the advanced features and durability of KP481 for mid-range customers, and the premium quality and performance of KP781 for older, more health-conscious customers.
#
# 3. **Product Development**: Use the insights from customer profiles to inform product development efforts. Consider introducing new features or variations of existing products to better cater to the preferences of different demographic segments. For example, for KP281, consider adding customizable workout routines or interactive features to enhance user engagement.
#
# 4. **Sales and Distribution Channels**: Optimize sales and distribution channels based on the identified customer profiles. Ensure that products are available where the target demographic is most likely to purchase them. For instance, KP281 may perform well in online marketplaces targeting younger audiences, while KP781 may have better success in specialty fitness stores targeting older, more affluent customers.
#
# 5. **Customer Engagement and Loyalty**: Implement strategies to enhance customer engagement and foster loyalty. Offer personalized recommendations, discounts, or rewards programs tailored to the preferences and behaviors of each customer segment. Encourage customer feedback and use it to continuously improve products and services.
#
# 6. **Market Expansion**: Explore opportunities for market expansion based on the identified customer profiles. Consider targeting new demographics or geographic regions that exhibit similar characteristics to the existing customer base. Conduct market research to understand the needs and preferences of these potential customers and tailor offerings accordingly.
#
# By leveraging these recommendations, AeroFit can effectively capitalize on its customer insights to drive growth, increase customer satisfaction, and maintain a competitive edge in the fitness equipment market.
